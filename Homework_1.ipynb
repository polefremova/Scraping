# %% [markdown]
# ## Урок 1. Основы клиент-серверного взаимодействия. Работа с API

# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
from pprint import pprint
import json

# %% [markdown]
# запрос в общем вид имеет вид:

# %%
# https://api.github.com/users/USERNAME/repos

# %%
user_name = 'polefremova'
url = f'https://api.github.com/users/{user_name}/repos'

# %%
resp = requests.get(url = url).json()

# %%
with open('resp1.json', 'w', encoding = 'UTF-8') as f:
  json.dump(resp, f)

# %%
all_repos = []

for el in resp:
  all_repos.append(el['description'])
pprint(all_repos)
# Out:
# ['Algorithms and Data Structures in Python',
#  None,
#  None,
#  'Parsing API',
#  None,
#  None]

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
# Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
import json

# %%
app_id = 'f7f0f462'
app_key = '41fad2a3202bcb1b2957d7e65c360d6e'
endpoint = "entries"
language_code = "en-us"
word_id = "world"
headers2 = {'app_id' : app_id, 'app_key' : app_key}

url2 = 'https://od-api.oxforddictionaries.com/api/v2/'+ endpoint + "/" + language_code + "/" + word_id.lower()

# %%
resp2 = requests.get(url = url2, headers = headers2)

# %%
pprint(resp2.text)
# Out:
# ('{\n'
#  '    "id": "world",\n'
#  '    "metadata": {\n'
#  '        "operation": "retrieve",\n'
#  '        "provider": "Oxford University Press",\n'
#  '        "schema": "RetrieveEntry"\n'
#  '    },\n'
#  '    "results": [\n'
#  '        {\n'
#  '            "id": "world",\n'
#  '            "language": "en-us",\n'
#  '            "lexicalEntries": [\n'
#  '                {\n'
#  '                    "entries": [\n'
#  '                        {\n'
#  '                            "etymologies": [\n'
#  '                                "Old English w(e)oruld, from a Germanic '
#  'compound meaning ‘age of man’; related to Dutch wereld and German Welt"\n'
#  '                            ],\n'
#  '                            "pronunciations": [\n'
#  '                                {\n'
#  '                                    "dialects": [\n'
#  '                                        "American English"\n'
#  '                                    ],\n'
# ...

# %%
resp2.status_code
# Out:
# 200

# %%
resp2 = resp2.json()

# %%
with open('resp2.json', 'w', encoding='UTF-8') as f:
  json.dump(resp2, f)
